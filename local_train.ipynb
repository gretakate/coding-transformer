# %% [markdown]
# # Local Training
#
# Use this notebook to train your transformer model locally.

# %%
# !export PYTHONPATH=.

# %% [markdown]
# Look in config.py for an extended list of configurations you can change.

# %%
from config import get_config

cfg = get_config()
cfg['lang_src'] = 'en'
cfg['lang_tgt'] = 'it'
cfg['model_folder'] = 'weights'
cfg['tokenizer_file'] = 'vocab/tokenizer{0}.json'
cfg['batch_size'] = 24
cfg['num_epochs'] = 30
cfg['preload'] = None  # Change this to 'latest' or a particular epoch number to resume training from a checkpoint

# %%
from train import train_model

train_model(cfg)
