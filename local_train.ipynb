# %%
# !export PYTHONPATH=.

# %%
from config import get_config
cfg = get_config()
cfg['model_folder'] = 'weights'
cfg['tokenizer_file'] = 'test_vocab/tokenizer{0}.json'
cfg['batch_size'] = 24
cfg['num_epochs'] = 31
cfg['preload'] = '29'

# %%
from train import train_model

train_model(cfg)
# Out:
# Using device cpu
# ...
# Max length of source sentence: 309
# Max length of target sentence: 274
# Loading model weights/tmodel_29.pt
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 3
#       1 from train import train_model
# ----> 3 train_model(cfg)
#
# File ~/Documents/Personal/PersonalProject/coding-transformer/train.py:213, in train_model(config)
#     211 if model_filename:
#     212     print(f"Loading model {model_filename}")
# --> 213     state = torch.load(model_filename)
#     214     initial_epoch = state['epoch'] + 1
#     215     optimizer.load_state_dict(state['optimizer_state_dict'])
#
# File ~/Documents/Personal/PersonalProject/coding-transformer/venv/lib/python3.9/site-packages/torch/serialization.py:809, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     807             except RuntimeError as e:
# ...
