# %%
from config import get_config
from translate import Translator

# %%
from config import get_weights_file_path
cfg = get_config()
cfg['model_folder'] = 'weights'
cfg['tokenizer_file'] = 'vocab/tokenizer{0}.json'
cfg['preload'] = '29'
model_filename = get_weights_file_path(cfg, cfg['preload'])
model_filename
# Out:
# 'weights/tmodel_29.pt'

# %%
translator = Translator()
translator.load_model(cfg)
# Out:
# Using device: cpu

# %%
t = translator.translate("Why do I need to translate this?")
t
# Out:
# "Perché volevo quest ' oggi ?"

# %%
t = translator.translate("How is my Italian?")
t
# Out:
# 'Come sta la mia in Chi è l ’ italiana ?'

# %%
t = translator.translate("My projects this week have been crazy, it's like playing whack-a-mole!")
t
# Out:
# 'Le mio « hanno ».'

# %%
t = translator.translate("Where is the bathroom?")
t
# Out:
# "Dov ’ è l ' i i ?"
